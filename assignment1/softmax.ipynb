# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.398280
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.477379 analytic: 1.477379, relative error: 3.259613e-08
# numerical: 0.949029 analytic: 0.949028, relative error: 4.679749e-08
# numerical: -2.175787 analytic: -2.175787, relative error: 1.677507e-08
# numerical: 5.337541 analytic: 5.337541, relative error: 2.575371e-08
# numerical: 0.340422 analytic: 0.340422, relative error: 1.548166e-07
# numerical: 0.108754 analytic: 0.108754, relative error: 9.292297e-07
# numerical: 2.416552 analytic: 2.416552, relative error: 2.462410e-08
# numerical: 2.763718 analytic: 2.763718, relative error: 1.049667e-08
# numerical: 1.431296 analytic: 1.431296, relative error: 2.938847e-08
# numerical: 0.587839 analytic: 0.587839, relative error: 1.311056e-08
# numerical: -5.587379 analytic: -5.587379, relative error: 3.393711e-09
# numerical: -2.297493 analytic: -2.297493, relative error: 1.443576e-08
# numerical: 0.274072 analytic: 0.274072, relative error: 1.618916e-07
# numerical: -3.157663 analytic: -3.157664, relative error: 1.983291e-08
# numerical: -0.708105 analytic: -0.708106, relative error: 7.358234e-08
# numerical: -0.576600 analytic: -0.576600, relative error: 4.520473e-09
# numerical: -2.575135 analytic: -2.575135, relative error: 1.047446e-08
# numerical: -2.950415 analytic: -2.950415, relative error: 4.475660e-10
# numerical: -2.464398 analytic: -2.464398, relative error: 5.258861e-09
# numerical: -1.231321 analytic: -1.231321, relative error: 2.077709e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.398280e+00 computed in 0.070240s
# vectorized loss: 2.398280e+00 computed in 0.009623s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

learning_rates = [1e-7, 5e-5, 5e-4,5e-3]
regularization_strengths = [2.5e4, 5e4,5e-3,5e-2]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

from itertools import product
for a,b in product(learning_rates,regularization_strengths):
    classif = Softmax()
    loss_hist = classif.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, verbose=True)
    y_train_pred = classif.predict(X_train)
    ac_train=np.mean(y_train == y_train_pred)
    y_val_pred = classif.predict(X_val)
    ac_val=np.mean(y_val == y_val_pred)
    results[(a,b)]=(ac_train,ac_val)
    if best_val < ac_val:
        best_val=ac_val
        best_svm=svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 776.639348
# iteration 100 / 1500: loss 285.211831
# iteration 200 / 1500: loss 105.664199
# iteration 300 / 1500: loss 39.982070
# iteration 400 / 1500: loss 15.987789
# iteration 500 / 1500: loss 7.151393
# iteration 600 / 1500: loss 3.948284
# iteration 700 / 1500: loss 2.776708
# iteration 800 / 1500: loss 2.411330
# iteration 900 / 1500: loss 2.179732
# iteration 1000 / 1500: loss 2.114458
# iteration 1100 / 1500: loss 2.055139
# iteration 1200 / 1500: loss 2.073917
# iteration 1300 / 1500: loss 2.082133
# iteration 1400 / 1500: loss 2.139565
# iteration 0 / 1500: loss 792.140165
# iteration 100 / 1500: loss 290.586754
# iteration 200 / 1500: loss 107.540699
# iteration 300 / 1500: loss 40.695119
# iteration 400 / 1500: loss 16.213700
# iteration 500 / 1500: loss 7.230769
# iteration 600 / 1500: loss 4.018526
# iteration 700 / 1500: loss 2.757762
# iteration 800 / 1500: loss 2.315918
# iteration 900 / 1500: loss 2.115162
# iteration 1000 / 1500: loss 2.093040
# iteration 1100 / 1500: loss 2.116087
# iteration 1200 / 1500: loss 2.129049
# iteration 1300 / 1500: loss 2.108830
# iteration 1400 / 1500: loss 2.018968
# iteration 0 / 1500: loss 770.986546
# iteration 100 / 1500: loss 283.171488
# iteration 200 / 1500: loss 104.834608
# iteration 300 / 1500: loss 39.713349
# iteration 400 / 1500: loss 15.888910
# iteration 500 / 1500: loss 7.136918
# iteration 600 / 1500: loss 3.915962
# iteration 700 / 1500: loss 2.749705
# iteration 800 / 1500: loss 2.393811
# iteration 900 / 1500: loss 2.140960
# iteration 1000 / 1500: loss 2.186907
# iteration 1100 / 1500: loss 2.083992
# iteration 1200 / 1500: loss 2.073549
# iteration 1300 / 1500: loss 2.115256
# iteration 1400 / 1500: loss 2.070333
# iteration 0 / 1500: loss 766.047287
# iteration 100 / 1500: loss 281.255514
# iteration 200 / 1500: loss 104.179942
# iteration 300 / 1500: loss 39.562524
# iteration 400 / 1500: loss 15.803763
# iteration 500 / 1500: loss 7.044015
# iteration 600 / 1500: loss 3.934065
# iteration 700 / 1500: loss 2.804360
# iteration 800 / 1500: loss 2.364368
# iteration 900 / 1500: loss 2.157865
# iteration 1000 / 1500: loss 2.126053
# iteration 1100 / 1500: loss 2.078249
# iteration 1200 / 1500: loss 2.061411
# iteration 1300 / 1500: loss 2.095914
# iteration 1400 / 1500: loss 2.090239
# iteration 0 / 1500: loss 777.151728
# iteration 100 / 1500: loss 285.312905
# iteration 200 / 1500: loss 105.742889
# iteration 300 / 1500: loss 40.039783
# iteration 400 / 1500: loss 15.974688
# iteration 500 / 1500: loss 7.220189
# iteration 600 / 1500: loss 4.009289
# iteration 700 / 1500: loss 2.722738
# iteration 800 / 1500: loss 2.348844
# iteration 900 / 1500: loss 2.215253
# iteration 1000 / 1500: loss 2.108530
# iteration 1100 / 1500: loss 2.079789
# iteration 1200 / 1500: loss 2.079881
# iteration 1300 / 1500: loss 2.090268
# iteration 1400 / 1500: loss 2.084698
# iteration 0 / 1500: loss 775.026684
# iteration 100 / 1500: loss 284.879816
# iteration 200 / 1500: loss 105.462064
# iteration 300 / 1500: loss 39.904573
# iteration 400 / 1500: loss 15.964144
# iteration 500 / 1500: loss 7.220611
# iteration 600 / 1500: loss 3.942137
# iteration 700 / 1500: loss 2.732386
# iteration 800 / 1500: loss 2.347565
# iteration 900 / 1500: loss 2.166596
# iteration 1000 / 1500: loss 2.119537
# iteration 1100 / 1500: loss 2.085516
# iteration 1200 / 1500: loss 2.098420
# iteration 1300 / 1500: loss 2.108258
# iteration 1400 / 1500: loss 2.052458
# iteration 0 / 1500: loss 769.827794
# iteration 100 / 1500: loss 282.598631
# iteration 200 / 1500: loss 104.704217
# iteration 300 / 1500: loss 39.674375
# iteration 400 / 1500: loss 15.771661
# iteration 500 / 1500: loss 7.121103
# iteration 600 / 1500: loss 3.939767
# iteration 700 / 1500: loss 2.744641
# iteration 800 / 1500: loss 2.382102
# iteration 900 / 1500: loss 2.140576
# iteration 1000 / 1500: loss 2.096696
# iteration 1100 / 1500: loss 2.096940
# iteration 1200 / 1500: loss 2.086149
# iteration 1300 / 1500: loss 2.103856
# iteration 1400 / 1500: loss 2.029529
# iteration 0 / 1500: loss 773.675744
# iteration 100 / 1500: loss 283.865589
# iteration 200 / 1500: loss 105.089086
# iteration 300 / 1500: loss 39.804897
# iteration 400 / 1500: loss 15.883163
# iteration 500 / 1500: loss 7.076466
# iteration 600 / 1500: loss 3.929130
# iteration 700 / 1500: loss 2.785408
# iteration 800 / 1500: loss 2.289475
# iteration 900 / 1500: loss 2.167314
# iteration 1000 / 1500: loss 2.110429
# iteration 1100 / 1500: loss 2.080683
# iteration 1200 / 1500: loss 2.074275
# iteration 1300 / 1500: loss 2.099799
# iteration 1400 / 1500: loss 2.081324
# iteration 0 / 1500: loss 780.227567
# iteration 100 / 1500: loss 286.558235
# iteration 200 / 1500: loss 106.148305
# iteration 300 / 1500: loss 40.227716
# iteration 400 / 1500: loss 16.002600
# iteration 500 / 1500: loss 7.193193
# iteration 600 / 1500: loss 3.928718
# iteration 700 / 1500: loss 2.776886
# iteration 800 / 1500: loss 2.320333
# iteration 900 / 1500: loss 2.178132
# iteration 1000 / 1500: loss 2.089218
# iteration 1100 / 1500: loss 2.106578
# iteration 1200 / 1500: loss 2.122722
# iteration 1300 / 1500: loss 2.071626
# iteration 1400 / 1500: loss 2.096626
# iteration 0 / 1500: loss 776.952877
# iteration 100 / 1500: loss 285.309234
# iteration 200 / 1500: loss 105.600438
# iteration 300 / 1500: loss 40.037827
# iteration 400 / 1500: loss 15.969357
# iteration 500 / 1500: loss 7.156370
# iteration 600 / 1500: loss 3.926025
# iteration 700 / 1500: loss 2.819796
# iteration 800 / 1500: loss 2.306882
# iteration 900 / 1500: loss 2.197215
# iteration 1000 / 1500: loss 2.105637
# iteration 1100 / 1500: loss 2.182283
# iteration 1200 / 1500: loss 2.097001
# iteration 1300 / 1500: loss 2.065120
# iteration 1400 / 1500: loss 2.103177
# iteration 0 / 1500: loss 772.531348
# iteration 100 / 1500: loss 283.794113
# iteration 200 / 1500: loss 105.099913
# iteration 300 / 1500: loss 39.846185
# iteration 400 / 1500: loss 15.900204
# iteration 500 / 1500: loss 7.130280
# iteration 600 / 1500: loss 3.867818
# iteration 700 / 1500: loss 2.765289
# iteration 800 / 1500: loss 2.314163
# iteration 900 / 1500: loss 2.180946
# iteration 1000 / 1500: loss 2.087328
# iteration 1100 / 1500: loss 2.075969
# iteration 1200 / 1500: loss 2.071763
# iteration 1300 / 1500: loss 2.059446
# iteration 1400 / 1500: loss 2.070967
# iteration 0 / 1500: loss 766.636302
# iteration 100 / 1500: loss 281.133922
# iteration 200 / 1500: loss 104.238934
# iteration 300 / 1500: loss 39.525685
# iteration 400 / 1500: loss 15.835805
# iteration 500 / 1500: loss 7.093852
# iteration 600 / 1500: loss 3.897380
# iteration 700 / 1500: loss 2.812990
# iteration 800 / 1500: loss 2.318164
# iteration 900 / 1500: loss 2.157780
# iteration 1000 / 1500: loss 2.095229
# iteration 1100 / 1500: loss 2.144354
# iteration 1200 / 1500: loss 2.087131
# iteration 1300 / 1500: loss 2.098359
# iteration 1400 / 1500: loss 2.074284
# iteration 0 / 1500: loss 772.587104
# iteration 100 / 1500: loss 283.493984
# iteration 200 / 1500: loss 104.839992
# iteration 300 / 1500: loss 39.719538
# iteration 400 / 1500: loss 15.887041
# iteration 500 / 1500: loss 7.122967
# iteration 600 / 1500: loss 3.889887
# iteration 700 / 1500: loss 2.822998
# iteration 800 / 1500: loss 2.338393
# iteration 900 / 1500: loss 2.220233
# iteration 1000 / 1500: loss 2.156457
# iteration 1100 / 1500: loss 2.150110
# iteration 1200 / 1500: loss 2.076174
# iteration 1300 / 1500: loss 2.111596
# iteration 1400 / 1500: loss 2.069521
# iteration 0 / 1500: loss 780.365230
# iteration 100 / 1500: loss 286.501248
# iteration 200 / 1500: loss 106.156101
# iteration 300 / 1500: loss 40.198142
# iteration 400 / 1500: loss 16.046318
# iteration 500 / 1500: loss 7.197919
# iteration 600 / 1500: loss 3.977857
# iteration 700 / 1500: loss 2.788372
# iteration 800 / 1500: loss 2.318478
# iteration 900 / 1500: loss 2.193582
# iteration 1000 / 1500: loss 2.138464
# iteration 1100 / 1500: loss 2.115399
# iteration 1200 / 1500: loss 2.078126
# iteration 1300 / 1500: loss 2.054641
# iteration 1400 / 1500: loss 2.113482
# iteration 0 / 1500: loss 776.934118
# iteration 100 / 1500: loss 285.332819
# iteration 200 / 1500: loss 105.651063
# iteration 300 / 1500: loss 39.964503
# iteration 400 / 1500: loss 15.932346
# iteration 500 / 1500: loss 7.150245
# iteration 600 / 1500: loss 3.895142
# iteration 700 / 1500: loss 2.802022
# iteration 800 / 1500: loss 2.395609
# iteration 900 / 1500: loss 2.135393
# iteration 1000 / 1500: loss 2.121194
# iteration 1100 / 1500: loss 2.083463
# iteration 1200 / 1500: loss 2.090283
# iteration 1300 / 1500: loss 2.071525
# iteration 1400 / 1500: loss 2.082887
# iteration 0 / 1500: loss 780.601563
# iteration 100 / 1500: loss 286.622084
# iteration 200 / 1500: loss 106.230709
# iteration 300 / 1500: loss 40.199384
# iteration 400 / 1500: loss 16.067861
# iteration 500 / 1500: loss 7.155501
# iteration 600 / 1500: loss 3.951393
# iteration 700 / 1500: loss 2.765197
# iteration 800 / 1500: loss 2.331563
# iteration 900 / 1500: loss 2.173251
# iteration 1000 / 1500: loss 2.119314
# iteration 1100 / 1500: loss 2.068346
# iteration 1200 / 1500: loss 2.077860
# iteration 1300 / 1500: loss 2.069773
# iteration 1400 / 1500: loss 2.087853
# lr 1.000000e-07 reg 5.000000e-03 train accuracy: 0.324918 val accuracy: 0.326000
# lr 1.000000e-07 reg 5.000000e-02 train accuracy: 0.331816 val accuracy: 0.344000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.332306 val accuracy: 0.348000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.330449 val accuracy: 0.344000
# lr 5.000000e-05 reg 5.000000e-03 train accuracy: 0.326224 val accuracy: 0.339000
# lr 5.000000e-05 reg 5.000000e-02 train accuracy: 0.330347 val accuracy: 0.344000
# lr 5.000000e-05 reg 2.500000e+04 train accuracy: 0.331286 val accuracy: 0.340000
# lr 5.000000e-05 reg 5.000000e+04 train accuracy: 0.325939 val accuracy: 0.347000
# lr 5.000000e-04 reg 5.000000e-03 train accuracy: 0.329939 val accuracy: 0.351000
# lr 5.000000e-04 reg 5.000000e-02 train accuracy: 0.329531 val accuracy: 0.334000
# lr 5.000000e-04 reg 2.500000e+04 train accuracy: 0.331143 val accuracy: 0.343000
# lr 5.000000e-04 reg 5.000000e+04 train accuracy: 0.331939 val accuracy: 0.350000
# lr 5.000000e-03 reg 5.000000e-03 train accuracy: 0.324898 val accuracy: 0.341000
# lr 5.000000e-03 reg 5.000000e-02 train accuracy: 0.324776 val accuracy: 0.339000
# lr 5.000000e-03 reg 2.500000e+04 train accuracy: 0.326429 val accuracy: 0.348000
# lr 5.000000e-03 reg 5.000000e+04 train accuracy: 0.323939 val accuracy: 0.339000
# best validation accuracy achieved during cross-validation: 0.351000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
